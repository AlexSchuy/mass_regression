# %%
from training.run import Run
# Out:
# /home/alex/.local/share/virtualenvs/mass_regression-6Kpx9UwL/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/alex/.local/share/virtualenvs/mass_regression-6Kpx9UwL/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# ...

# %%
config = {'model_name': 'keras', 'seed': 0, 'dataset': 'Wlnu', 'hidden_layers': [10], 'train_size': 10, 'test_size': 1000}
run = Run(config)
# Out:
# /home/alex/.local/share/virtualenvs/mass_regression-6Kpx9UwL/lib/python3.7/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# /home/alex/.local/share/virtualenvs/mass_regression-6Kpx9UwL/lib/python3.7/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# WARNING:tensorflow:From /home/alex/.local/share/virtualenvs/mass_regression-6Kpx9UwL/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# ...

# %%
from evaluation.metrics import print_metrics
from evaluation.plot import plot_prediction

# %%
print_metrics(run)
# Out:
# Printing metrics for run at /home/alex/mass-regression/mass_regression/results/007.
# 	Testing score = -2.3050681426950357
# 	Training score = 0.9999999999990037
# 	Training time = 66.835369348526
# 	Jigsaw score = -1.3440200076534108
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      23.124378      0.034221         0.029127        0.010384
# 1      17.182490      0.157217         0.024932        0.003649
# 2      38.715966      0.080510         0.025915        0.007297
# 3      47.206464      0.116088         0.016057        0.001809
# 4       4.095495      0.026134         0.030405        0.000950
# 5       4.759841      0.044674         0.034750        0.005630
# 6      23.963969      0.345362         0.032503        0.010698
# 7       9.075908      0.267873         0.053990        0.013497
# 8      30.601298      1.826886         0.019163        0.004537
# 9      20.822447      0.678268         0.033140        0.008211
#
# ...

# %%
run.result['testing_score']
# Out:
# -2.3050681426950357

# %%
plot_prediction(run)
