# %%
from visualization.higgs_visualization import Plotter
from training.datasets.h import HiggsDataset
from pathlib import Path
import definitions
import plotly
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import numpy as np
import pandas as pd

from scipy import signal

# %%
plotter_nu = Plotter(mass=125, target_name='nu', loss_name='nu', log_dir=definitions.LOG_DIR / 'H125' / 'nu' / 'model_v1-nu_loss')
plotter_wm = Plotter(mass=125, target_name='nu', loss_name='wm', log_dir=definitions.LOG_DIR / 'H125' / 'nu' / 'model_v1-Wm_loss')
plotter_hm = Plotter(mass=125, target_name='nu', loss_name='hm', log_dir=definitions.LOG_DIR / 'H125' / 'nu' / 'model_v1-Hm_loss')
# Out:
# yer_Sub_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_37 (TensorFlo [(None,)]            0           tf_op_layer_Pow_50[0][0]
#                                                                  tf_op_layer_Pow_51[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Pow_52 (TensorFlowO [(None,)]            0           tf_op_layer_strided_slice_22[0][0
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_23 (T [(None,)]            0           tf_op_layer_AddV2_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_25 (TensorFlo [(None,)]            0           tf_op_layer_AddV2_24[0][0]
#                                                                  tf_op_layer_Pow_32[0][0]
# ...

# %%
h400_dataset = HiggsDataset(mass=400)
h400_hm_pad = HiggsDataset(mass=400, pad_features=['Hm_gen'])

# %%
plotter_wm.mass_plot(hm_plot_range=(250, 550), dataset=h400_dataset)

# %%
plotter_hm.mass_plot(hm_plot_range=(250, 550), dataset=h400_hm_pad)

# %%
plotter_hm_400 = plotter_hm = Plotter(mass=400, target_name='nu', loss_name='hm', log_dir=definitions.LOG_DIR / 'H400' / 'nu' / 'model_v1-Hm_loss')
# Out:
# yer_Sub_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_69 (TensorFlo [(None,)]            0           tf_op_layer_Pow_95[0][0]
#                                                                  tf_op_layer_Pow_96[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Pow_97 (TensorFlowO [(None,)]            0           tf_op_layer_strided_slice_36[0][0
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_37 (T [(None,)]            0           tf_op_layer_AddV2_54[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_57 (TensorFlo [(None,)]            0           tf_op_layer_AddV2_56[0][0]
#                                                                  tf_op_layer_Pow_77[0][0]
# ...

# %%
h750_hm_pad = HiggsDataset(mass=750, pad_features=['Hm_gen'])

# %%
plotter_hm_400.mass_plot(hm_plot_range=(100, 1100), dataset=h750_hm_pad)
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.

# %%
h125_hm_pad = HiggsDataset(mass=125, pad_features=['Hm_gen'])

# %%
plotter_hm_400.mass_plot(hm_plot_range=(50, 250), dataset=h125_hm_pad)

# %% [markdown]
# # Mixed dataset

# %%
plotter_mixed = Plotter(mass=[125, 400, 750], target_name='nu', loss_name='hm', log_dir=definitions.LOG_DIR / 'H125_400_750' / 'nu' / 'model_v1-Hm_loss')
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-3-f4f9dec69b9d> in <module>
# ----> 1 plotter_mixed = Plotter(mass=[125, 400, 750], target_name='nu', loss_name='hm', log_dir=definitions.LOG_DIR / 'H125_400_750' / 'nu' / 'model_v1-Hm_loss')
#
# ~\work\mass_regression\mass_regression\visualization\higgs_visualization.py in __init__(self, mass, target_name, loss_name, log_dir)
#      25             loss = HmLoss
#      26         self.dataset = HiggsDataset(mass=mass, target_name=target_name, pad_features=pad_features)
# ---> 27         self.hparams, self.model = Model_V1_Factory(self.dataset, loss).load(self.run_dir)
#      28         self.load_deltas(log_dir)
#      29
#
# ~\work\mass_regression\mass_regression\training\models\model_v1_factory.py in load(self, run_dir)
#      36
#      37     def load(self, run_dir):
# ...
